# %% [markdown]
# # F8

# %% [markdown]
# ## Task

# %% [markdown]
# OpenStreetMapのデータを用いたテーマを自由に設定し、データを抽出し、結果を地図で示せ.
# →東京都内にある大学を抽出し地図化する.

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)
# Out:
# /usr/local/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    SELECT pt.*
    FROM planet_osm_point AS pt, adm2 AS poly
    WHERE pt.amenity='university' AND
    poly.name_1='Tokyo' AND
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.7138, 139.7627], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    1420766756   None           None             None               None
# 1    1420766770   None           None             None               None
# 2    1420766759   None           None             None               None
# 3    1420766774   None           None             None               None
# 4    1420795631   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 265  1420783786   None           None             None               None
# 266  1420771429   None           None             None               None
# 267  1420787847   None           None             None               None
# 268  1420787846   None           None             None               None
# 269  6135576744   None           None             None               None
#
#     admin_level aerialway aeroway     amenity  area barrier bicycle brand  \
# 0          None      None    None  university  None    None    None  None
# 1          None      None    None  university  None    None    None  None
# 2          None      None    None  university  None    None    None  None
# 3          None      None    None  university  None    None    None  None
# 4          None      None    None  university  None    None    None  None
# ..          ...       ...     ...         ...   ...     ...     ...   ...
# 265        None      None    None  university  None    None    None  None
# 266        None      None    None  university  None    None    None  None
# 267        None      None    None  university  None    None    None  None
# 268        None      None    None  university  None    None    None  None
# 269        None      None    None  university  None    None    None  None
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 265   None     None     None    None         None    None    None    None
# 266   None     None     None    None         None    None    None    None
# 267   None     None     None    None         None    None    None    None
# 268   None     None     None    None         None    None    None    None
# 269   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 265         None    None  None       None  None             None    None
# 266         None    None  None       None  None             None    None
# 267         None    None  None       None  None             None    None
# 268         None    None  None       None  None             None    None
# 269         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 265    None     None  None         None     None    None  None    None  None
# 266    None     None  None         None     None    None  None    None  None
# 267    None     None  None         None     None    None  None    None  None
# 268    None     None  None         None     None    None  None    None  None
# 269    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar           name natural office oneway operator  \
# 0       None     None     None  亜細亜大学（国際関係学部）    None   None   None     None
# 1       None     None     None    亜細亜大学（経営学部）    None   None   None     None
# 2       None     None     None     亜細亜大学（法学部）    None   None   None     None
# 3       None     None     None    亜細亜大学（経済学部）    None   None   None     None
# 4       None     None     None      立教大学（法学部）    None   None   None     None
# ..       ...      ...      ...            ...     ...    ...    ...      ...
# 265     None     None     None   東京学芸大学（教育学部）    None   None   None     None
# 266     None     None     None   嘉悦大学（経営経済学部）    None   None   None     None
# 267     None     None     None    法政大学（情報科学部）    None   None   None     None
# 268     None     None     None      法政大学（工学部）    None   None   None     None
# 269     None     None     None          朝鮮大学校    None   None   None     None
#
#     place   poi population power power_source public_transport railway   ref  \
# 0    None  None       None  None         None             None    None  None
# 1    None  None       None  None         None             None    None  None
# 2    None  None       None  None         None             None    None  None
# 3    None  None       None  None         None             None    None  None
# 4    None  None       None  None         None             None    None  None
# ..    ...   ...        ...   ...          ...              ...     ...   ...
# 265  None  None       None  None         None             None    None  None
# 266  None  None       None  None         None             None    None  None
# 267  None  None       None  None         None             None    None  None
# 268  None  None       None  None         None             None    None  None
# 269  None  None       None  None         None             None    None  None
#
#     religion route service  shop sport surface  toll tourism tower:type  \
# 0       None  None    None  None  None    None  None    None       None
# 1       None  None    None  None  None    None  None    None       None
# 2       None  None    None  None  None    None  None    None       None
# 3       None  None    None  None  None    None  None    None       None
# 4       None  None    None  None  None    None  None    None       None
# ..       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 265     None  None    None  None  None    None  None    None       None
# 266     None  None    None  None  None    None  None    None       None
# 267     None  None    None  None  None    None  None    None       None
# 268     None  None    None  None  None    None  None    None       None
# 269     None  None    None  None  None    None  None    None       None
#
#     tunnel water waterway wetland width  wood z_order  \
# 0     None  None     None    None  None  None    None
# 1     None  None     None    None  None  None    None
# 2     None  None     None    None  None  None    None
# 3     None  None     None    None  None  None    None
# 4     None  None     None    None  None  None    None
# ..     ...   ...      ...     ...   ...   ...     ...
# 265   None  None     None    None  None  None    None
# 266   None  None     None    None  None  None    None
# 267   None  None     None    None  None  None    None
# 268   None  None     None    None  None  None    None
# 269   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15533003.108 4260109.138)
# 1    POINT (15533003.286 4260113.716)
# 2    POINT (15533003.108 4260121.242)
# 3    POINT (15533003.108 4260125.684)
# 4    POINT (15551546.441 4263542.924)
# ..                                ...
# 265  POINT (15528076.675 4260105.272)
# 266  POINT (15530858.204 4262272.264)
# 267  POINT (15531523.026 4260707.527)
# 268  POINT (15531522.258 4260758.513)
# 269  POINT (15523354.101 4262746.937)
#
# [270 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7810a481ccc8f7fce9efcf54fb3f40f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7810a481ccc8f7fce9efcf54fb3f40f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7810a481ccc8f7fce9efcf54fb3f40f4 = L.map(
#                 &quot;map_7810a481ccc8f7fce9efcf54fb3f40f4&quot;,
#                 {
#                     center: [35.7138, 139.7627],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db0f0ed3bca4f85b66640eb7ce17f027 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#             var marker_bfbede0e7ed3d3f7fc18407bb0306551 = L.marker(
#                 [35.705027399707504, 139.535341],
#                 {}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#         var popup_c6cb2daecdac527e02a73b3a170d3030 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9e26324711d399907c450c17d45d554 = $(`&lt;div id=&quot;html_b9e26324711d399907c450c17d45d554&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;亜細亜大学（国際関係学部）&lt;/div&gt;`)[0];
#                 popup_c6cb2daecdac527e02a73b3a170d3030.setContent(html_b9e26324711d399907c450c17d45d554);
#
#
#
#         marker_bfbede0e7ed3d3f7fc18407bb0306551.bindPopup(popup_c6cb2daecdac527e02a73b3a170d3030)
#         ;
#
#
#
#
#             var marker_dda856b06f0784f44fc3aeca96a0a37d = L.marker(
#                 [35.7050607997075, 139.5353426],
#                 {}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#         var popup_6b244dc0ad312f6aef98bba4d2b22d71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66cb015215e53e41b38b62620622d807 = $(`&lt;div id=&quot;html_66cb015215e53e41b38b62620622d807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;亜細亜大学（経営学部）&lt;/div&gt;`)[0];
#                 popup_6b244dc0ad312f6aef98bba4d2b22d71.setContent(html_66cb015215e53e41b38b62620622d807);
#
#
#
#         marker_dda856b06f0784f44fc3aeca96a0a37d.bindPopup(popup_6b244dc0ad312f6aef98bba4d2b22d71)
#         ;
#
#
#
#
#             var marker_16cc8225548d69da0fa404b1fc721aec = L.marker(
#                 [35.70511569970752, 139.535341],
#                 {}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#         var popup_6be566fb57b05787b90f3755081df73b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d0c8a8ba91bceb97dc95b704a72075b = $(`&lt;div id=&quot;html_8d0c8a8ba91bceb97dc95b704a72075b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;亜細亜大学（法学部）&lt;/div&gt;`)[0];
#                 popup_6be566fb57b05787b90f3755081df73b.setContent(html_8d0c8a8ba91bceb97dc95b704a72075b);
#
#
#
#         marker_16cc8225548d69da0fa404b1fc721aec.bindPopup(popup_6be566fb57b05787b90f3755081df73b)
#         ;
#
#
#
#
#             var marker_d5ec90c450e5c47f6c83ddc01080229d = L.marker(
#                 [35.70514809970752, 139.535341],
#                 {}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#         var popup_d0cde9bb1e0bffcb8e6db3fb525c5cd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_466cdbe6770a511cdad5df70798bb8de = $(`&lt;div id=&quot;html_466cdbe6770a511cdad5df70798bb8de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;亜細亜大学（経済学部）&lt;/div&gt;`)[0];
#                 popup_d0cde9bb1e0bffcb8e6db3fb525c5cd0.setContent(html_466cdbe6770a511cdad5df70798bb8de);
#
#
#
#         marker_d5ec90c450e5c47f6c83ddc01080229d.bindPopup(popup_d0cde9bb1e0bffcb8e6db3fb525c5cd0)
#         ;
#
#
#
#
#             var marker_b507cab85a6bdb7e3cf22ef967993a1d = L.marker(
#                 [35.73007159970979, 139.7019186],
#                 {}
#             ).addTo(map_7810a481ccc8f7fce9efcf54fb3f40f4);
#
#
#         var popup_7888629ae66c62d4f7dab27722ee3ea4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65f007551e474aadaaf44840c93a7f86 = $(`&lt;div id=&quot;html_65f007551e474aadaaf44840c93a7f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;立教大学（法学部）&lt;/div&gt;`)[0];
#                 popup_7888629ae66c62d4f7dab27722ee3ea4.setContent(html_65f007551e474aadaaf44840c93a7f86);
#
#
#
#         marker_b507cab85a6bdb7e3cf22ef967993a1d.bindPopup(popup_7888629ae66c62d4f7dab27722ee3ea4)
#         ;
#
#
#
#
#             var marker_39d6b157362707a18bdb98b3241ccc98 = L.marker(
#                 [35.711
